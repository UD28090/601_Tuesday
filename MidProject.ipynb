# %% [markdown]
# # DATA 601 MID-TERM PROJECT:
#
# ## Name of the dataset:Default of credit card clients data set
#
# DATA SOURCE LOCATION:
#
# https://archive.ics.uci.edu/ml/datasets/default+of+credit+card+clients
# In the above link inside the data folder we are using default of "credit card clients.xls" is the data which I am using in the project
# Description of how data is found:
# When I was looking for an intresting data set in the finance sectors to play with numbers, I found this dataset which includes the details of the default credit card users.
#
# Documentary Data Analyzis:
#
#     Numeric: float, int
#     Totat Variables: 23
#         X1: Credit amout
#         X2: Gender (1 = male; 2 = female).
#         X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).
#         X4: Marital status (1 = married; 2 = single; 3 = others).
#         X5: Age (year).
#         X6 - X11: History of past payment.
#         The measurement of the repayment status is
#                 -1=pay duly;
#                  1=payment delay for one month;
#                  2=payment delay for two months;
#                  .
#                  .
#                  8=payment delay for eight months;
#                  9=payment delay for nine months and above;
#         X6 = the repayment status in September,2005
#         X7 = the repayment status in August, 2005
#         X8 = the repayment status in July, 2005
#         X9 = the repayment status in June, 2005
#         X10 = the repayment status in May, 2005
#         X11 = the repayment status in April, 2005
#         X12-X17: Amount of bill statement (NT dollar)
#         X12 = amount of bill statement in September, 2005
#         X13 = amount of bill statement in August, 2005;
#         X14 = amount of bill statement in July, 2005;
#         X15 = amount of bill statement in June, 2005;
#         X14 = amount of bill statement in May, 2005;
#         X17 = amount of bill statement in April, 2005
#         X18-X23: Amount of previous payment (NT dollar)
#         X18 = amount paid in September, 2005;
#         X19 = amount paid in August, 2005;
#         X19 = amount paid in July, 2005;
#         X19 = amount paid in June, 2005;
#         X23 = amount paid in April, 2005.
#
#
#
# Data size:
#
# The dataset is of the size of 5.5MB
#
# Dataset contains one table.
#
# First dataset which is a batting data contains 30,000 rows 25 columns(includes 23 )

# %% [markdown]
# ## 1.1 LOADING LIBRARIES

# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### LOAD DATA

# %%
df = pd.read_excel("/Users/akhilaamaranayani/Downloads/601/akhila/credit_card_clients.xls")

# %% [markdown]
# ## FILE STRUCTURE AND CONTENT

# %%
df.head(30000)
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26     -1      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29995      29995      80000    1          2         2   34      2      2
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43     -1     -1
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1     -1
#
#           X8     X9  ...        X15        X16        X17       X18       X19  \
# ...

# %%
#displaying the shape
df.shape
# Out:
# (30001, 25)

# %%
#displaying the datatype of the column
df.dtypes
# Out:
# Unnamed: 0    object
# X1            object
# X2            object
# X3            object
# X4            object
# X5            object
# X6            object
# X7            object
# X8            object
# X9            object
# X10           object
# X11           object
# X12           object
# X13           object
# X14           object
# X15           object
# X16           object
# X17           object
# X18           object
# X19           object
# X20           object
# X21           object
# X22           object
# X23           object
# Y             object
# dtype: object

# %%
#displaying the columns in the given data set
df.columns
# Out:
# Index(['Unnamed: 0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
#        'X20', 'X21', 'X22', 'X23', 'Y'],
#       dtype='object')

# %% [markdown]
# ## DATA CLEANING
# ### Dropping the row which is repeatedly named and a column which is the duplicate of the first column.

# %%
#displaying the repeated renaming of the columns
df.head(1)
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
#
#         X21       X22       X23                           Y
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
#
# [1 rows x 25 columns]

# %%
#renaming the column names
df.rename({'Unnamed:0': 'ID', 'X1':'LIMIT_BAL', 'X2':'SEX', 'X3':'EDUCATION', 'X4':'MARRIAGE', 'X5':'AGE', 'X6':'PAY_0', 'X7':'PAY_1', 'X8':'PAY_2', 'X9':'PAY_3','X10':'PAY_4', 'X11':'PAY_5', 'X12':'BILL_AMT1', 'X13':'BILL_AMT2', 'X14':'BILL_AMT3', 'X15':'BILL_AMT4', 'X16':'BILL_AMT5', 'X17':'BILL_AMT6', 'X18':'PAY_AMT1', 'X19':'PAY_AMT2','X20':'PAY_AMT3', 'X21':'PAY_AMT4', 'X22':'PAY_AMT5', 'X23':'PAY_AMT6', 'Y':'default payment next month'},axis=1,inplace=True)

# %%
del df["Unnamed: 0"]

# %%
df = df.drop(labels=0, axis=0)

# %% [markdown]
# ## MISSING VALUES

# %%
#checking for missisng values
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# ## Univariate Visualization
# First of all,let us look at some of the binary features.Looking at each feature might uncover some insight that might be useful at later modelling stages.

# %%
df.SEX.value_counts().plot.pie(autopct='%1.0f',title='GENDER')
plt.show()

# %% [markdown]
# The above pie chart represents the differentiation of female and male.

# %%
sns.countplot(df['AGE'])
plt.title('Overall age of people', fontsize=20)
plt.xlabel('AGE', fontsize=18)
plt.ylabel('PEOPLE', fontsize=16)
plt.show()
# Out:
# /Users/akhilaamaranayani/Anaconda3/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The above Bar Graph represents the differentiation of peoples by Age.

# %% [markdown]
# # Bivariate Visualization

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['MARRIAGE'],hue=df['AGE'],palette='Set1')
plt.title('AGE VS MARRIAGE', fontsize=20)
plt.xlabel('MARRIAGE',fontsize=18)
plt.ylabel('AGE', fontsize=16)
plt.show()
# Out:
# /Users/akhilaamaranayani/Anaconda3/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# it represents the number of observations per category for a categorical variable of Marriage with Age and displays the result as a bar chart.

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['AGE'],hue=df['EDUCATION'],palette='Set1')
plt.title('comparing Age vs Education', fontsize=20)
plt.xlabel('AGE',fontsize=18)
plt.ylabel('EDUCATION', fontsize=16)
plt.show()
# Out:
# /Users/akhilaamaranayani/Anaconda3/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# it represents the number of observations per category for a categorical variable of Education with Age and displays the result as a bar chart.

# %%
# Binary Features
plt.figure(figsize=(22, 6))
#fig, axs = plt.subplot(ncols=2)

# LIMIT_BAL
plt.subplot(131)
sns.countplot(df['LIMIT_BAL'])
plt.xlabel('LIMIT_BAL')
plt.ylabel('Frequency')


# AGE
plt.subplot(132)
sns.countplot(df['MARRIAGE'])
plt.xlabel('MARRIAGE')
plt.ylabel('Frequency')

# EDUCATION
plt.subplot(133)
sns.countplot(df['EDUCATION'])
plt.xlabel('EDUCATION')
plt.ylabel('Frequency')
# Out:
# /Users/akhilaamaranayani/Anaconda3/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/akhilaamaranayani/Anaconda3/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# it represents the number of observations per category for a each categorical variable of (LIIT_BAL, MARRIAGE, EDUCATION)and displays the result as a bar chart.

# %%
sns.set(style="white", palette="muted", color_codes=True)
f, axes = plt.subplots(2,2,figsize=(10, 10), sharex=False, sharey = False)
sns.despine(left=True)
sns.distplot(df['BILL_AMT1'].values, label = 'BILL_AMT1',color="b",bins = 100, ax=axes[0,0])
sns.distplot(df['BILL_AMT2'].values, label = 'BILL_AMT2',color="r",bins =100, ax=axes[1,0])
sns.distplot(df['BILL_AMT3'].values, label = 'BILL_AMT3',color="b",bins =100, ax=axes[0,1])
sns.distplot(df['BILL_AMT4'].values, label = 'BILL_AMT4',color="r",bins =100, ax=axes[1,1])
plt.setp(axes, yticks=[])
plt.tight_layout()
plt.show()
# Out:
# /Users/akhilaamaranayani/Anaconda3/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/akhilaamaranayani/Anaconda3/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(22, 6))
df_sub = df[df['BILL_AMT1'] < 1000]
sns.boxplot(data=df_sub)

plt.show()

# %%
plot=sns.displot(data=df,kind="ecdf",x="EDUCATION",hue="AGE",aspect=1.5)

# %% [markdown]
# it represents the displot with the variation of Education and Age.

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# this graphs represents the overall representation of dataset

# %%
DF1=pd.DataFrame(df,columns=['PAY_0','PAY_1','PAY_2','PAY_3','PAY_4','PAY_5'])
DF1.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# This graph represents about the payment of previous month

# %%
DF2=pd.DataFrame(df,columns=['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6'])
DF2.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# This graph represents about the payment of current and prevous month

# %%
DF3=pd.DataFrame(df,columns=['PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6'])
DF3.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# This graph represents about the completed transactions of credit card information.

# %% [markdown]
# ## LINEAR REGRESSION
# To estimate the real probability of default.With the response variable(Y) which represents default payment next month,and the predictive probability with the independent variable(X).

# %%
DF3=pd.DataFrame(df,columns=['default payment next month','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6'])
DF3.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# This graph represents the overall representation of completed payment list and default payment next month

# %%
DF3=pd.DataFrame(df,columns=['default payment next month','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6'])
DF3.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# This graph represents the overall representation of current and Previous payments and default payment next month

# %%
DF3=pd.DataFrame(df,columns=['default payment next month','PAY_0','PAY_1','PAY_2','PAY_3','PAY_4','PAY_5'])
DF3.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# This graph represents the overall representation of previous payments and default payment next month

# %% [markdown]
# Linear Regression is used to measure the real probability by default with response variable(Y) and independent variable(X).The simple linear regression result(Y=A+BX) shows that the forecasting model produced by artificial neural network  has the highest coefficient of determination;its regression intercept(A) is close to zero and regression coefficient(B) to one.Among all the techniques artificial network is the only one that can accurately estimate the real probability of default.
