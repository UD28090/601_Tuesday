# %% [markdown]
# # Final Project

# %% [markdown]
# # Data Source

# %% [markdown]
# Short description of the Dataset coulms

# %% [markdown]
# This is latest report of the covid data which is having both the Covid_Cases data and Covid_Testing data.here we can see the website where we can find that.
#
#
# --> public path of this repository is hosted at https://covid.ourworldindata.org/. For example, you can access the CSV for the complete dataset at https://covid.ourworldindata.org/data/owid-covid-data.csv

# %% [markdown]
# So, in the next step i'm explaining the coulmns with their description

# %% [markdown]
# Our whole COVID-19 dataset is a collection of data from Our World in Data's COVID-19 project.
# Confirmed cases
#
# Variables with description:
#
# total_cases: Total confirmed cases of COVID-19. Counts can include probable cases, where reported.
#
# new_cases:	New confirmed cases of COVID-19. Counts can include probable cases, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA.
#
# new_cases_smoothed:	New confirmed cases of COVID-19 (7-day smoothed). Counts can include probable cases, where reported.
#
# total_cases_per_million:	Total confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.
#
# new_cases_per_million:	New confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.
#
# new_cases_smoothed_per_million:	New confirmed cases of COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable cases, where reported.
#
# total_deaths	Total deaths attributed to COVID-19. Counts can include probable deaths, where reported.
#
# new_deaths:	New deaths attributed to COVID-19. Counts can include probable deaths, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA.
#
# new_deaths_smoothed:	New deaths attributed to COVID-19 (7-day smoothed). Counts can include probable deaths, where reported.
#
# total_deaths_per_million:	Total deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.
#
# new_deaths_per_million:	New deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.
#
# new_deaths_smoothed_per_million:	New deaths attributed to COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable deaths, where reported.
#
# Notes:
#
# Due to varying protocols and challenges in the attribution of the cause of death, the number of confirmed deaths may not accurately represent the true number of deaths caused by COVID-19.
# Excess mortality
#
#
# icu_patients:	Number of COVID-19 patients in intensive care units (ICUs) on a given day
#
# icu_patients_per_million:	Number of COVID-19 patients in intensive care units (ICUs) on a given day per 1,000,000 people
#
# hosp_patients:	Number of COVID-19 patients in hospital on a given day
#
# hosp_patients_per_million:	Number of COVID-19 patients in hospital on a given day per 1,000,000 people
#
# weekly_icu_admissions:	Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week
#
# weekly_icu_admissions_per_million:	Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week per 1,000,000 people
#
# weekly_hosp_admissions:	Number of COVID-19 patients newly admitted to hospitals in a given week
#
# weekly_hosp_admissions_per_million:	Number of COVID-19 patients newly admitted to hospitals in a given week per 1,000,000 people
#
# total_tests:	Total tests for COVID-19
#
# new_tests:	New tests for COVID-19 (only calculated for consecutive days)
#
# total_tests_per_thousand:	Total tests for COVID-19 per 1,000 people
#
# new_tests_per_thousand:	New tests for COVID-19 per 1,000 people
#
# new_tests_smoothed:	New tests for COVID-19 (7-day smoothed). For countries that don't report testing data on a daily basis, we assume that testing changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window
#
# new_tests_smoothed_per_thousand:	New tests for COVID-19 (7-day smoothed) per 1,000 people
#
# positive_rate:	The share of COVID-19 tests that are positive, given as a rolling 7-day average (this is the inverse of tests_per_case)
#
# tests_per_case:	Tests conducted per new confirmed case of COVID-19, given as a rolling 7-day average (this is the inverse of positive_rate)
#
# tests_units:	Units used by the location to report its testing data
#
# total_vaccinations:	Total number of COVID-19 vaccination doses administered
#
# people_vaccinated:	Total number of people who received at least one vaccine dose
#
# people_fully_vaccinated:	Total number of people who received all doses prescribed by the initial vaccination protocol
#
# total_boosters:	Total number of COVID-19 vaccination booster doses administered (doses administered beyond the number prescribed by the vaccination protocol)
#
# new_vaccinations:	New COVID-19 vaccination doses administered (only calculated for consecutive days)
#
# new_vaccinations_smoothed:	New COVID-19 vaccination doses administered (7-day smoothed). For countries that don't report vaccination data on a daily basis, we assume that vaccination changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window
#
# total_vaccinations_per_hundred:	Total number of COVID-19 vaccination doses administered per 100 people in the total population
#
# people_vaccinated_per_hundred:	Total number of people who received at least one vaccine dose per 100 people in the total population
#
# people_fully_vaccinated_per_hundred:	Total number of people who received all doses prescribed by the initial vaccination protocol per 100 people in the total population
#
# total_boosters_per_hundred:	Total number of COVID-19 vaccination booster doses administered per 100 people in the total population
#
# new_vaccinations_smoothed_per_million:	New COVID-19 vaccination doses administered (7-day smoothed) per 1,000,000 people in the total population
#
# new_people_vaccinated_smoothed:	Daily number of people receiving their first vaccine dose (7-day smoothed)
#
# new_people_vaccinated_smoothed_per_hundred:	Daily number of people receiving their first vaccine dose (7-day smoothed) per 100 people in the total population
#
# iso_code:	ISO 3166-1 alpha-3 – three-letter country codes
#
# continent:	Continent of the geographical location
#
# location:	Geographical location
#
# date:	Date of observation
#
# population_density:	Number of people divided by land area, measured in square kilometers, most recent year available
#
# median_age:	Median age of the population, UN projection for 2020
#
# aged_65_older:	Share of the population that is 65 years and older, most recent year available
#
# aged_70_older:	Share of the population that is 70 years and older in 2015
#
# gdp_per_capita:	Gross domestic product at purchasing power parity (constant 2011 international dollars), most recent year available
#
# extreme_poverty:	Share of the population living in extreme poverty, most recent year available since 2010
#
# cardiovasc_death_rate:	Death rate from cardiovascular disease in 2017 (annual number of deaths per 100,000 people)
#
# diabetes_prevalence:	Diabetes prevalence (% of population aged 20 to 79) in 2017
#
# female_smokers:	Share of women who smoke, most recent year available
#
# male_smokers:	Share of men who smoke, most recent year available
#
# handwashing_facilities:	Share of the population with basic handwashing facilities on premises, most recent year available
#
# hospital_beds_per_thousand:	Hospital beds per 1,000 people, most recent year available since 2010
#
# life_expectancy	:Life expectancy at birth in 2019
#
# human_development_index:	A composite index measuring average achievement in three basic dimensions of human development—a long and healthy life, knowledge and a decent standard of living. Values for 2019, imported from http://hdr.undp.org/en/indicators/137506

# %% [markdown]
# # World wide covid testing data Report - DF1

# %% [markdown]
# In this data set the Coivd Testing results are taken based on different ISO codes they are in subject to according to the locations listed and they are also categorized as mentioned above. in this we can find various data for each continent or iso_code

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt


import missingno as msno
import numpy as np
import seaborn as sns

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
#      |████████████████████████████████| 15.2 MB 3.1 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Covid testing data

# %% [markdown]
# Importing Covid testing data

# %% [markdown]
# In this data set we can see the world wide covid testing data. Here we have 187 rows and 19 columns. The primary key of the data set is iso_code.
# Here the data will be evaluated by using iso_code. for every Entity there is a Unique iso_code and also can see the overall data how to the testing process will do and described in very easy way to analyze.

# %%
covid_testing=pd.read_excel('covid-testing-data.xlsx')

covid_testing.rename(columns = {'ISO code': 'iso_code', 'Date': 'Testing_Date'}, inplace = True)

# %% [markdown]
# Overview of Covid testing data.

# %%
covid_testing.head()
# Out:
#   iso_code                         Entity Testing_Date  \
# 0      AFG  Afghanistan - tests performed   2022-03-12
# 1      ALB      Albania - tests performed   2022-05-09
# 2      DZA      Algeria - tests performed   2022-03-07
# 3      AND      Andorra - tests performed   2022-02-23
# 4      AGO       Angola - tests performed   2022-04-07
#
#                                           Source URL  \
# 0  http://www.emro.who.int/images/stories/coronav...
# 1  https://shendetesia.gov.al/covid19-ministria-e...
# 2                    https://africacdc.org/covid-19/
# 3                          https://covid19.govern.ad
# 4                    https://africacdc.org/covid-19/
#
#                                         Source label Notes  \
# 0  WHO Regional Office for the Eastern Mediterranean   NaN
# 1           Ministry of Health and Social Protection   NaN
# 2  Africa Centres for Disease Control and Prevention   NaN
# 3                  Tauler COVID-19, Govern d'Andorra   NaN
# ...

# %%
covid_testing.tail()
# Out:
#     iso_code                            Entity Testing_Date  \
# 182      VNM           Vietnam - people tested   2022-05-08
# 183      ESH  Western Sahara - tests performed   2022-04-20
# 184      YEM           Yemen - tests performed   2022-03-12
# 185      ZMB          Zambia - tests performed   2022-05-07
# 186      ZWE        Zimbabwe - tests performed   2022-05-08
#
#                                             Source URL  \
# 182  https://covid19.gov.vn/ngay-8-5-so-mac-moi-cov...
# 183                    https://africacdc.org/covid-19/
# 184  http://www.emro.who.int/images/stories/coronav...
# 185  https://zambia-open-data-nsdi-mlnr.hub.arcgis....
# 186                    https://africacdc.org/covid-19/
#
#                                           Source label Notes  \
# 182                      Ministry of Health of Vietnam   NaN
# 183  Africa Centres for Disease Control and Prevention   NaN
# 184  WHO Regional Office for the Eastern Mediterranean   NaN
# ...

# %% [markdown]
# # Analysing Data Covid Testing Data

# %%
covid_testing.shape
# Out:
# (187, 19)

# %%
covid_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 19 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   iso_code                                       187 non-null    object
#  1   Entity                                         187 non-null    object
#  2   Testing_Date                                   187 non-null    datetime64[ns]
#  3   Source URL                                     187 non-null    object
#  4   Source label                                   186 non-null    object
#  5   Notes                                          16 non-null     object
#  6   Number of observations                         187 non-null    int64
#  7   Cumulative total                               181 non-null    float64
#  8   Cumulative total per thousand                  181 non-null    float64
# ...

# %% [markdown]
# # Data Types of Covid Testiong data

# %%
covid_testing.dtypes
# Out:
# iso_code                                                 object
# Entity                                                   object
# Testing_Date                                     datetime64[ns]
# Source URL                                               object
# Source label                                             object
# Notes                                                    object
# Number of observations                                    int64
# Cumulative total                                        float64
# Cumulative total per thousand                           float64
# Daily change in cumulative total                        float64
# Daily change in cumulative total per thousand           float64
# 7-day smoothed daily change                             float64
# 7-day smoothed daily change per thousand                float64
# Short-term positive rate                                float64
# Short-term tests per case                               float64
# ...

# %% [markdown]
# Verifying the null values of Covid Testing data

# %%
covid_testing.isna().sum()
# Out:
# iso_code                                           0
# Entity                                             0
# Testing_Date                                       0
# Source URL                                         0
# Source label                                       1
# Notes                                            171
# Number of observations                             0
# Cumulative total                                   6
# Cumulative total per thousand                      6
# Daily change in cumulative total                 104
# Daily change in cumulative total per thousand    104
# 7-day smoothed daily change                       14
# 7-day smoothed daily change per thousand          14
# Short-term positive rate                          42
# Short-term tests per case                         49
# General source label                               0
# General source URL                                 0
# Short description                                  0
# ...

# %% [markdown]
# # World wide covid cases data Report - DF2

# %% [markdown]
# Importing Covid Cases data

# %% [markdown]
# In this data set we can see the world wide covid data. Here we have 184979 rows × 67 columns. The primary key of the data set is iso_code. Here the data will be evaluated by using iso_code. for every loaction there is a Unique iso_code and also can see the overall data how to the testing process will do and described in very easy way to analyze.

# %%
df2=pd.read_excel('world-covid-data.xlsx')
Covid_cases = df2.rename({'date': 'Case_Date'}, axis=1)
Covid_cases
# Out:
#        iso_code continent     location   Case_Date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 184974      ZWE    Africa     Zimbabwe  2022-05-05     248050.0        0.0
# 184975      ZWE    Africa     Zimbabwe  2022-05-06     248214.0      164.0
# 184976      ZWE    Africa     Zimbabwe  2022-05-07     248214.0        0.0
# 184977      ZWE    Africa     Zimbabwe  2022-05-08     248352.0      138.0
# 184978      ZWE    Africa     Zimbabwe  2022-05-09     248536.0      184.0
#
# ...

# %% [markdown]
# Overview of Covid cases data

# %%
Covid_cases.tail()
# Out:
#        iso_code continent  location   Case_Date  total_cases  new_cases  \
# 184974      ZWE    Africa  Zimbabwe  2022-05-05     248050.0        0.0
# 184975      ZWE    Africa  Zimbabwe  2022-05-06     248214.0      164.0
# 184976      ZWE    Africa  Zimbabwe  2022-05-07     248214.0        0.0
# 184977      ZWE    Africa  Zimbabwe  2022-05-08     248352.0      138.0
# 184978      ZWE    Africa  Zimbabwe  2022-05-09     248536.0      184.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 184974              38.000        5471.0         0.0                0.286
# 184975              53.143        5473.0         2.0                0.571
# 184976              48.429        5473.0         0.0                0.571
# 184977              63.000        5476.0         3.0                1.000
# 184978              85.857        5479.0         3.0                1.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
Covid_cases.head()
# Out:
#   iso_code continent     location   Case_Date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# # Analysing of Covid Cases data

# %%
Covid_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184979 entries, 0 to 184978
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    184979 non-null  object
#  1   continent                                   174178 non-null  object
#  2   location                                    184979 non-null  object
#  3   Case_Date                                   184979 non-null  object
#  4   total_cases                                 178113 non-null  float64
#  5   new_cases                                   177846 non-null  float64
#  6   new_cases_smoothed                          176677 non-null  float64
#  7   total_deaths                                159799 non-null  float64
#  8   new_deaths                                  159781 non-null  float64
# ...

# %%
Covid_cases.shape
# Out:
# (184979, 67)

# %% [markdown]
# # DataTypes for Covid Cases

# %%
Covid_cases.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# Case_Date                                   object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# # Verifying the null values for Covid cases

# %%
Covid_cases.isna().sum()
# Out:
# iso_code                                        0
# continent                                   10801
# location                                        0
# Case_Date                                       0
# total_cases                                  6866
#                                             ...
# human_development_index                     36083
# excess_mortality_cumulative_absolute       178562
# excess_mortality_cumulative                178562
# excess_mortality                           178562
# excess_mortality_cumulative_per_million    178562
# Length: 67, dtype: int64

# %% [markdown]
# # Merging 2 Data Sets

# %% [markdown]
# Combing 2 data sets which Covid cases and Covid testing data

# %% [markdown]
# Here in this we are merging the 2 data sets where and which  we are having a primary key like iso_code based on that we can merge.

# %%
New_df = pd.merge(Covid_cases,covid_testing,on = "iso_code", how = 'left')
New_df
# Out:
#        iso_code continent     location   Case_Date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 184974      ZWE    Africa     Zimbabwe  2022-05-05     248050.0        0.0
# 184975      ZWE    Africa     Zimbabwe  2022-05-06     248214.0      164.0
# 184976      ZWE    Africa     Zimbabwe  2022-05-07     248214.0        0.0
# 184977      ZWE    Africa     Zimbabwe  2022-05-08     248352.0      138.0
# 184978      ZWE    Africa     Zimbabwe  2022-05-09     248536.0      184.0
#
# ...

# %% [markdown]
# overview of new dataset, i.e, Covid dataset

# %%
New_df.head()
# Out:
#   iso_code continent     location   Case_Date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    Daily change in cumulative total  \
# 0                               NaN
# ...

# %%
New_df.tail()
# Out:
#        iso_code continent  location   Case_Date  total_cases  new_cases  \
# 184974      ZWE    Africa  Zimbabwe  2022-05-05     248050.0        0.0
# 184975      ZWE    Africa  Zimbabwe  2022-05-06     248214.0      164.0
# 184976      ZWE    Africa  Zimbabwe  2022-05-07     248214.0        0.0
# 184977      ZWE    Africa  Zimbabwe  2022-05-08     248352.0      138.0
# 184978      ZWE    Africa  Zimbabwe  2022-05-09     248536.0      184.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 184974              38.000        5471.0         0.0                0.286
# 184975              53.143        5473.0         2.0                0.571
# 184976              48.429        5473.0         0.0                0.571
# 184977              63.000        5476.0         3.0                1.000
# 184978              85.857        5479.0         3.0                1.286
#
#         ...  Daily change in cumulative total  \
# ...

# %%
msno.matrix(New_df);

# %% [markdown]
# showing the null vlaues with the graphical representation

# %% [markdown]
# # Analysing the Covid data set

# %%
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184979 entries, 0 to 184978
# Data columns (total 85 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   iso_code                                       184979 non-null  object
#  1   continent                                      174178 non-null  object
#  2   location                                       184979 non-null  object
#  3   Case_Date                                      184979 non-null  object
#  4   total_cases                                    178113 non-null  float64
#  5   new_cases                                      177846 non-null  float64
#  6   new_cases_smoothed                             176677 non-null  float64
#  7   total_deaths                                   159799 non-null  float64
#  8   new_deaths                                     159781 non-null  float64
# ...

# %% [markdown]
# # Sanity Check

# %% [markdown]
# Here we can see the for the Case_Date the dtype is object. so, i'm converting object to datetime formate

# %%
New_df.Case_Date.head(2)
# Out:
# 0    2020-02-24
# 1    2020-02-25
# Name: Case_Date, dtype: object

# %%
    
New_df.Testing_Date.head(2)
# Out:
# 0   2022-03-12
# 1   2022-03-12
# Name: Testing_Date, dtype: datetime64[ns]

# %% [markdown]
# we can see those two date formates are same but the dtype is different so i'm changing the Case_Date dtype

# %%
New_df['Case_Date'] = pd.to_datetime(New_df['Case_Date'])

# %% [markdown]
# In the above we can see their is object as a data type for the colums

# %%
New_df = New_df.convert_dtypes()
New_df.dtypes
# Out:
# iso_code                             string
# continent                            string
# location                             string
# Case_Date                    datetime64[ns]
# total_cases                           Int64
#                                   ...
# Short-term tests per case           Float64
# General source label                 string
# General source URL                   string
# Short description                    string
# Detailed description                 string
# Length: 85, dtype: object

# %%
New_df.dtypes
# Out:
# iso_code                             string
# continent                            string
# location                             string
# Case_Date                    datetime64[ns]
# total_cases                           Int64
#                                   ...
# Short-term tests per case           Float64
# General source label                 string
# General source URL                   string
# Short description                    string
# Detailed description                 string
# Length: 85, dtype: object

# %% [markdown]
# After converstion of data types we can see the object is changed to strings and for the Case_Date the data type changed to date formate which is datetime64[ns]

# %% [markdown]
# In the dataset we have multiple data types are there intially in different formate but now we converted everthing into well defeined way.

# %%
New_df.shape
# Out:
# (184979, 85)

# %% [markdown]
# Verifying the Null values for new data set

# %%
New_df.isna().sum()
# Out:
# iso_code                         0
# continent                    10801
# location                         0
# Case_Date                        0
# total_cases                   6866
#                              ...
# Short-term tests per case    75582
# General source label         37336
# General source URL           37336
# Short description            37336
# Detailed description         37336
# Length: 85, dtype: int64

# %% [markdown]
# DataTypes for the new dataset..i.e, Covid data set

# %%
New_df1.astype({"Cumulative total":'int',"Short-term positive rate":'int',"Short-term tests per case":'int',"new_cases":'int',"total_cases":'int',"total_deaths":'int',"total_deaths_per_million":'int',"hosp_patients_per_million":'int',"people_vaccinated_per_hundred":'int',"people_fully_vaccinated_per_hundred":'int',"total_boosters_per_hundred":'int',"Cumulative total per thousand":'int'})
# Out:
#        iso_code       location      continent  Cumulative total  \
# 10308       AUS      Australia        Oceania          69970822
# 10309       AUS      Australia        Oceania          69970822
# 10310       AUS      Australia        Oceania          69970822
# 10311       AUS      Australia        Oceania          69970822
# 10312       AUS      Australia        Oceania          69970822
# ...         ...            ...            ...               ...
# 175090      USA  United States  North America         875302588
# 175091      USA  United States  North America         875302588
# 175092      USA  United States  North America         875302588
# 175093      USA  United States  North America         875302588
# 175094      USA  United States  North America         875302588
#
#         Short-term positive rate  Short-term tests per case  new_cases  \
# 10308                          0                          5       2524
# ...

# %%
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184979 entries, 0 to 184978
# Data columns (total 85 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   iso_code                                       184979 non-null  string
#  1   continent                                      174178 non-null  string
#  2   location                                       184979 non-null  string
#  3   Case_Date                                      184979 non-null  datetime64[ns]
#  4   total_cases                                    178113 non-null  Int64
#  5   new_cases                                      177846 non-null  Int64
#  6   new_cases_smoothed                             176677 non-null  Float64
#  7   total_deaths                                   159799 non-null  Int64
#  8   new_deaths                                     159781 non-null  Int64
# ...

# %% [markdown]
# We can see the Unique values of iso_code. which is interlinked column in our dataset.

# %%
New_df.iso_code.unique()
# Out:
# <StringArray>
# [     'AFG', 'OWID_AFR',      'ALB',      'DZA',      'AND',      'AGO',
#       'AIA',      'ATG',      'ARG',      'ARM',
#  ...
#       'VUT',      'VAT',      'VEN',      'VNM',      'WLF',      'ESH',
#  'OWID_WRL',      'YEM',      'ZMB',      'ZWE']
# Length: 243, dtype: string

# %% [markdown]
# Now, We can see the count of overall iso_code.

# %%
len(pd.unique(New_df['iso_code']))
# Out:
# 243

# %%
New_df.location.unique()
# Out:
# <StringArray>
# [        'Afghanistan',              'Africa',             'Albania',
#              'Algeria',             'Andorra',              'Angola',
#             'Anguilla', 'Antigua and Barbuda',           'Argentina',
#              'Armenia',
#  ...
#              'Vanuatu',             'Vatican',           'Venezuela',
#              'Vietnam',   'Wallis and Futuna',      'Western Sahara',
#                'World',               'Yemen',              'Zambia',
#             'Zimbabwe']
# Length: 243, dtype: string

# %%
len(pd.unique(New_df['location']))
# Out:
# 243

# %% [markdown]
# By the above count of iso_code, location. we can say that the data is perfect because for every country there is a  specific iso_code which is unique to each country. #243 (count)

# %% [markdown]
# Now, form here we can see the individual count and unique values of each continent

# %%
New_df.continent.count()
# Out:
# 174178

# %%
net =(New_df['continent']).unique()
net
# Out:
# <StringArray>
# ['Asia', <NA>, 'Europe', 'Africa', 'North America', 'South America',
#  'Oceania']
# Length: 7, dtype: string

# %%
a=New_df.groupby('continent')
a.get_group('Oceania')['location'].unique()
# Out:
# <StringArray>
# [               'Australia',             'Cook Islands',
#                      'Fiji',         'French Polynesia',
#                      'Guam',                 'Kiribati',
#          'Marshall Islands',     'Micronesia (country)',
#                     'Nauru',            'New Caledonia',
#               'New Zealand',                     'Niue',
#  'Northern Mariana Islands',                    'Palau',
#          'Papua New Guinea',                 'Pitcairn',
#                     'Samoa',          'Solomon Islands',
#                   'Tokelau',                    'Tonga',
#                    'Tuvalu',                  'Vanuatu',
#         'Wallis and Futuna']
# Length: 23, dtype: string

# %%
a=New_df.groupby('continent')
a.get_group('South America')['location'].unique()
# Out:
# <StringArray>
# [       'Argentina',          'Bolivia',           'Brazil',
#             'Chile',         'Colombia',          'Ecuador',
#  'Falkland Islands',           'Guyana',         'Paraguay',
#              'Peru',         'Suriname',          'Uruguay',
#         'Venezuela']
# Length: 13, dtype: string

# %%
a=New_df.groupby('continent')
a.get_group('Asia')['location'].unique()
# Out:
# <StringArray>
# [         'Afghanistan',              'Armenia',           'Azerbaijan',
#               'Bahrain',           'Bangladesh',               'Bhutan',
#                'Brunei',             'Cambodia',                'China',
#               'Georgia',            'Hong Kong',                'India',
#             'Indonesia',                 'Iran',                 'Iraq',
#                'Israel',                'Japan',               'Jordan',
#            'Kazakhstan',               'Kuwait',           'Kyrgyzstan',
#                  'Laos',              'Lebanon',                'Macao',
#              'Malaysia',             'Maldives',             'Mongolia',
#               'Myanmar',                'Nepal',      'Northern Cyprus',
#                  'Oman',             'Pakistan',            'Palestine',
#           'Philippines',                'Qatar',         'Saudi Arabia',
#             'Singapore',          'South Korea',            'Sri Lanka',
# ...

# %%
a=New_df.groupby('continent')
a.get_group('North America')['location'].unique()
# Out:
# <StringArray>
# [                        'Anguilla',              'Antigua and Barbuda',
#                             'Aruba',                          'Bahamas',
#                          'Barbados',                           'Belize',
#                           'Bermuda',  'Bonaire Sint Eustatius and Saba',
#            'British Virgin Islands',                           'Canada',
#                    'Cayman Islands',                       'Costa Rica',
#                              'Cuba',                          'Curacao',
#                          'Dominica',               'Dominican Republic',
#                       'El Salvador',                        'Greenland',
#                           'Grenada',                        'Guatemala',
#                             'Haiti',                         'Honduras',
#                           'Jamaica',                           'Mexico',
#                        'Montserrat',                        'Nicaragua',
# ...

# %%
a=New_df.groupby('continent')
a.get_group('Europe')['location'].unique()
# Out:
# <StringArray>
# [               'Albania',                'Andorra',                'Austria',
#                 'Belarus',                'Belgium', 'Bosnia and Herzegovina',
#                'Bulgaria',                'Croatia',                 'Cyprus',
#                 'Czechia',                'Denmark',                'Estonia',
#          'Faeroe Islands',                'Finland',                 'France',
#                 'Germany',              'Gibraltar',                 'Greece',
#                'Guernsey',                'Hungary',                'Iceland',
#                 'Ireland',            'Isle of Man',                  'Italy',
#                  'Jersey',                 'Kosovo',                 'Latvia',
#           'Liechtenstein',              'Lithuania',             'Luxembourg',
#                   'Malta',                'Moldova',                 'Monaco',
#              'Montenegro',            'Netherlands',        'North Macedonia',
# ...

# %%
net =(New_df['location']).unique()
net
# Out:
# <StringArray>
# [        'Afghanistan',              'Africa',             'Albania',
#              'Algeria',             'Andorra',              'Angola',
#             'Anguilla', 'Antigua and Barbuda',           'Argentina',
#              'Armenia',
#  ...
#              'Vanuatu',             'Vatican',           'Venezuela',
#              'Vietnam',   'Wallis and Futuna',      'Western Sahara',
#                'World',               'Yemen',              'Zambia',
#             'Zimbabwe']
# Length: 243, dtype: string

# %% [markdown]
# For Asia the Continent of the geographical location count is, which means the overall is,
# The Asia contient is having 50 countries.
# The Europe contient is having 51 countries.
# The Africa contient is having 54 countries.
# The North America contient is having 54 countries.
# The South America contient is having 13 countries.
# The Oceania contient is having 14 countries.

# %%
(New_df[New_df['continent'] == "North America"]).count()
# Out:
# iso_code                     28737
# continent                    28737
# location                     28737
# Case_Date                    28737
# total_cases                  26761
#                              ...
# Short-term tests per case    18265
# General source label         20619
# General source URL           20619
# Short description            20619
# Detailed description         20619
# Length: 85, dtype: int64

# %%
(New_df[New_df['continent'] == "South America"]).count()
# Out:
# iso_code                     10362
# continent                    10362
# location                     10362
# Case_Date                    10362
# total_cases                  10299
#                              ...
# Short-term tests per case     8005
# General source label          8809
# General source URL            8809
# Short description             8809
# Detailed description          8809
# Length: 85, dtype: int64

# %%
(New_df[New_df['continent'] == "Oceania"]).count()
# Out:
# iso_code                     12182
# continent                    12182
# location                     12182
# Case_Date                    12182
# total_cases                   9195
#                              ...
# Short-term tests per case     3036
# General source label          6183
# General source URL            6183
# Short description             6183
# Detailed description          6183
# Length: 85, dtype: int64

# %%
(New_df[New_df['continent'] == "nan"]).count()
# Out:
# iso_code                     0
# continent                    0
# location                     0
# Case_Date                    0
# total_cases                  0
#                             ..
# Short-term tests per case    0
# General source label         0
# General source URL           0
# Short description            0
# Detailed description         0
# Length: 85, dtype: int64

# %% [markdown]
# Here i'm picking most wanted coulums from the data frame and droping the rest coulums
# And also removing the rows which is having the nan values. by that we will get the actual data to analyze

# %%
New_df1= New_df[['iso_code','location','continent','Cumulative total','Short-term positive rate','Short-term tests per case','new_cases','total_cases','total_deaths','total_deaths_per_million','hosp_patients_per_million','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred','total_boosters_per_hundred','Cumulative total per thousand']]

New_df1=New_df1.dropna()

# %%
New_df1
# Out:
#        iso_code       location      continent  Cumulative total  \
# 10308       AUS      Australia        Oceania          69970822
# 10309       AUS      Australia        Oceania          69970822
# 10310       AUS      Australia        Oceania          69970822
# 10311       AUS      Australia        Oceania          69970822
# 10312       AUS      Australia        Oceania          69970822
# ...         ...            ...            ...               ...
# 175090      USA  United States  North America         875302588
# 175091      USA  United States  North America         875302588
# 175092      USA  United States  North America         875302588
# 175093      USA  United States  North America         875302588
# 175094      USA  United States  North America         875302588
#
#         Short-term positive rate  Short-term tests per case  new_cases  \
# 10308                      0.192                        5.2       2524
# ...

# %%
New_df1.shape
# Out:
# (6021, 15)

# %% [markdown]
# In the above we get the actual data and shape of the new data frame

# %% [markdown]
# Now, we are starting the visualization process of the data frame.

# %% [markdown]
# # Visualization

# %% [raw]
# By this graphs we can analyse how a covid effect to people and how many fighted against that

# %%
msno.matrix(New_df1);

# %% [markdown]
# showing the null vlaues with the graphical representation

# %% [markdown]
# # lag Plot

# %% [markdown]
# A lag plot is a special type of scatter plot in which the X-axis represents the dataset with some time units behind or ahead as compared to the Y-axis. The difference between these time units is called lag or lagged and it is represented by k.
#
# The lag plot contains the following axes:
#
# Vertical axis: Yi for all i
# Horizontal axis: Yi-k for all i, where k is lag value

# %% [markdown]
# Now, lets check whether total_cases data matters or not

# %%
pd.plotting.lag_plot(New_df1['total_cases']);

# %% [markdown]
# Lag plot showing good auto correlation in the total_cases data

# %% [markdown]
# Now, lets check whether Short-term tests per case data matters or not
# Data matters to the total_deaths for this dataset
# By this data we can use this for futher references

# %%
pd.plotting.lag_plot(New_df1['Short-term tests per case']);

# %% [markdown]
# Lag plot showing weak auto correlation in the Short-term tests per case data

# %% [markdown]
# # PIE Chart

# %% [markdown]
# pie chart using the plot() function of pandas library. You should pass the plot type as 'pie' in the kind argument.

# %% [markdown]
# Here i want to show the short tearm tests that is being taken and also for that how much positive rate is coming up.

# %%
df4.plot(kind='pie', title='overall representation of the short term tests with their positve rate',ylabel='')
# Out:
# <AxesSubplot:title={'center':'overall representation of the short term tests with their positve rate'}>

# %% [markdown]
# So, if we see this pie chart only 1% of positive rate has there in overall covid tests

# %% [markdown]
# # Histogram

# %% [markdown]
# A histogram is a great tool for quickly assessing a probability distribution that is intuitively understood by almost any audience.

# %% [markdown]
# Here i wants to show how many total cases are there and in that how many deaths are happening

# %% [markdown]
# To plot a graph for that is not clear so for the better understanding purpose i'm using some statistics method like mean method

# %% [markdown]
# Now, i'm calulating the mean,sum values for the total_cases, total_deaths

# %%
df2 = New_df1[["total_cases","total_deaths"]].sum()
print(df2)
# Out:
# total_cases     36206959010
# total_deaths      499424196
# dtype: int64

# %%
dfmean1 = New_df1[["total_cases","total_deaths"]].mean()
print(dfmean1)
# Out:
# total_cases     6.013446e+06
# total_deaths    8.294705e+04
# dtype: float64

# %% [markdown]
# The Mean values for the total_cases = 6, total_deaths = 8

# %% [markdown]
# Now, lets place a graph for the total_cases, total_deaths

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# By looking this graph we can easily say that is only less than 1 % of death rate is happen in the world wide due to covid

# %% [markdown]
# Historgram for vaccinations records

# %% [markdown]
# Before going to plot a graph i'm evaluating the mean vallues for the columns

# %%
df4 = New_df1[['Short-term positive rate','Short-term tests per case']].mean()
df4
# Out:
# Short-term positive rate      0.129855
# Short-term tests per case    11.801329
# dtype: float64

# %%
df3 = New_df1[['Short-term positive rate','Short-term tests per case']].sum()
df3
# Out:
# Short-term positive rate       781.8574
# Short-term tests per case    71055.8000
# dtype: float64

# %%
df3 = New_df1[['people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred','total_boosters_per_hundred']].mean()
df3
# Out:
# people_vaccinated_per_hundred          61.189302
# people_fully_vaccinated_per_hundred    55.057447
# total_boosters_per_hundred             18.709655
# dtype: float64

# %%
df3 = New_df1[['people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred','total_boosters_per_hundred']].sum()
df3
# Out:
# people_vaccinated_per_hundred          368420.79
# people_fully_vaccinated_per_hundred    331500.89
# total_boosters_per_hundred             112650.83
# dtype: float64

# %% [markdown]
# Here is the mean values for the vaccinations
#
# like:
#     people_vaccinated_per_hundred is the people who has taken the first dose of vaccination
#     people_fully_vaccinated_per_hundred is the people who are done with their second dose of vaccination
#     total_boosters_per_hundred is the people who are taken booster dose which is final vaccination for the Covid

# %%
df3.plot.bar(x='people_vaccinated_per_hundred', y='people_fully_vaccinated_per_hundred', rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# By This garph we can say that in the world 60% of people taken first dose of Covid vaccine, 55% of people taken second dose of Covid vaccine and finaly only 15% of people taken the booster short
#
# lets hope we will complete all the vaccine within short period
#
# from past few days again the covid cases are increasing so takecare of our self and stay safe

# %% [markdown]
# # Conclusion

# %% [markdown]
# After looking to the data set intially i'm exicted to evaluate the Covid data because of the Covid-19 everyone faced lots of problems like in a finacial way, professional way.. etc and also due to that many people lost their employment. soon after now we are slowly overcoming the struggles and problems that we have faced in the lockdown

# %% [markdown]
# At the Intial stage of  Covid to upto now the overall Covid cases are 36206959010 in that 99 % people got recovered. this is the happyist thing which is happen.
#
# And the rest 1% people are having some other health problems so they can't sustain that covid disease.

# %% [markdown]
# for the Covid disease our great scientists tie up with the pharma comapanies and they discovered different vaccinations by multiple formulas
#
# there are three different stages of vaccination has came up so, people has to take their doses
#
# for the fist dose 368420 people has taken
# for the second dose 331500 people has taken
# for the Booster dose which is final vaccination 112650 people has taken

# %% [markdown]
# Basically to diagnosis the covid there we have taken mutilple for the people who are having some symptoms they decribed in the General source label, eneral source URL, Short description, Detailed description coulms we can verify them
#
# If someone is having the Symptoms then that person may come to Covid test
#
# the Overall amount of the people taking the Covid is 71055 for every minute
#
# In that the positive rate of the Covid is 781
#
# By this we can say less than 10% postive rate of Covid occured as per the report
