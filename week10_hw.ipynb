# %% [markdown]
# # Week 10 Homework
#
# Extend the following class and name this class `ModuleLister`
#
# This will find all unique modules in your homework and labs.

# %%
### DON'T CHANGE THIS CELL


import os

class FileProcessor:
    
    def __init__(self, path, file_types=['.ipynb']):
        self.files = self.find_all_files(path, file_types)
        print(f'{len(self.files)} file(s) found...')

    
    def find_all_files(self, path, file_types):
        paths = []
        for root, dirs, files in os.walk(path):
            for file in files:
                if any([file.endswith(ft) for ft in file_types]):
                    path = os.path.join(root, file)
                    # print(path)
                    paths.append(path)
        return paths
    
    def read_file(self, file_path, encoding='utf8'):
        with open(file_path,encoding=encoding) as f:
            return f.read()
    
    def start(self):
        """
        Entry point for the class
        """
        for file in self.files:
            self.process_file(file)
        
    def process_file(self, file_path):
        """
        abstract method
        """
        raise NotImplemented('process_file method not implemented')

# %%
class ModuleLister(FileProcessor):
    def __init__(self,path):
        super().__init__(path)
        
    def process_file(self, file_path):
        l = processor.read_file(file_path)
        T = l.split(',')
        for j in range(len(T)):
            if 'import' in T[j]:
                O = T[j].split('import')
                length = len(O)
                print(O[length-1])  
    pass

# %%
processor = ModuleLister(path=r'/Users/akhilaamaranayani/Downloads/601/601_Tuesday') # change the path according to your path
# Out:
# 110 file(s) found...

# %%
processor.start()
# Out:
#  pandas as pd\n"
#  os\n"
#  pyplot as plt\n"
#  seaborn as sns"
#    ]
#   }
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  os\n"
#  request\n"
#  ZipFile\n"
#  pandas as pd\n"
#  csv\n"
#  request\n"
#  ZipFile\n"
#  ZipFile"
#    ]
#   }
#  request\n"
#  csv\n"
#  numpy as np\n"
#  matplotlib.pyplot as plt\n"
#  csv\n"
#  ZipFile"
#    ]
#   }
#  request\n"
#  pandas as pd\n"
#  pandas as pd\n"
#  numpy as np\n"
#    ]
#   }
#  re\n"
#  re"
#    ]
#   }
#  re\n"
#  pandas as pd"
#    ]
#   }
#  re\n"
#  pandas as pd\n"
# ant part of your role at work: (Select all that apply) - Other - Text\n"
#  pandas as pd\n"
# ant part of your role at work: (Select all that apply) - Other - Text\n"
#  pandas as pd"
#    ]
#   }
#  re\n"
#  pandas as pd"
#    ]
#   }
#  re\n"
#  pandas as pd"
#    ]
#   }
#  re\n"
#  numpy as np\n"
#    ]
#   }
#  re\n"
#  re"
#    ]
#   }
#  re\n"
#  Firefox
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  browserhistory as bh"
#    ]
#   }
#  pandas as pd"
#    ]
#   }
#  urlparse\n"
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  Firefox
#  browserhistory as bh"
#    ]
#   }
#  pandas as pd"
#    ]
#   }
#  urlparse\n"
#  fuzzywuzzy"
#    ]
#   }
#  fuzz\n"
#  pandas as pd\n"
#  csv"
#    ]
#   }
#  json library\n"
#  json"
#    ]
#   }
#  request\n"
#  pandas as pd\n"
#  ZipFile"
#    ]
#   }
#  chardet"
#    ]
#   }
#  numpy as np\n"
#    ]
#   }
#  re\n"
#  re"
#    ]
#   }
#  re\n"
#  pandas as pd\n"
#  pandas as pd"
#    ]
#   }
#  datetime module\n"
#  datetime\n"
#  datetime\n"
#    ]
#   }
#  datetime from datetime? \n"
#  parser from dateutil\n"
#  parser\n"
#    ]
#   }
#  numpy as np"
#    ]
#   }
#  pandas\n"
#  pandas as pd"
#    ]
#   }
#  matplotlib.pyplot as plt\n"
#  seaborn"
#    ]
#   }
#  dates\n"
#  Firefox
#  pandas as pd\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  browserhistory as bh"
#    ]
#   }
#  pandas as pd"
#    ]
#   }
#  urlparse\n"
#  pandas as pd"
#    ]
#   }
#  pandas as pd\n"
#  request\n"
#  sqlite\n"
#  sqlite3"
#    ]
#   }
#  pandas as pd\n"
#  pandas as pd\n"
#  seaborn\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy\n"
#  numpy as np"
#    ]
#   }
#  seaborn as sns\n"
#  seaborn as sns\n"
#  seaborn as sns\n"
#  pandas as pd\n"
#  pandas as pd\n"
#  time\n"
#  pandas\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  time\n"
#  pandas\n"
#  time\n"
#  pandas\n"
#  pandas\n"
#  or set low_memory=False.\n"
#  time\n"
#  pandas\n"
#  pandas as pd\n"
#  missingno as msno"
#    ]
#   }
#  matplotlib.pylab as plt"
#    ]
#   }
#  time\n"
#  pandas\n"
#  time\n"
#  pandas\n"
#  pandas as pd\n"
#  matplotlib.pylab as plt"
#    ]
#   }
#  random"
#    ]
#   }
#  timeit\n"
#  this"
#    ]
#   }
# ant.\n"
#  random\n"
#  random\n"
#  pandas\n"
#  matplotlib.pyplot as plt\n"
#  numpy"
#    ]
#   }
#  random \n"
#  matplotlib.pyplot as plt\n"
#  seaborn\n"
#  pandas\n"
#  numpy"
#    ]
#   }
#  pandas\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt\n"
#  datetime\n"
#  matplotlib\n"
#  matplotlib.pyplot as plt\n"
#    ]
#   }
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  colors\n"
#  PercentFormatter\n"
#  pandas as pd\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#    ]
#   }
#  random \n"
#  matplotlib.pyplot as plt\n"
#  pandas\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  csv"
#    ]
#   }
#  pandas"
#    ]
#   }
#  pandas as pd\n"
#  xmltodict\n"
#  json\n"
#  OrderedDict\n"
#  minidom\n"
#  xml.etree.ElementTree\n"
#  pandas \n"
#  json"
#    ]
#   }
#  pandas as pd\n"
#  random\n"
#  datetime\n"
#  re\n"
#  pandas\n"
#  pandas as pd\n"
#  numpy as np\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  pandas as pd\n"
#  pandas as pd\n"
#  numpy as np\n"
#  pandas as pd\n"
#  os\n"
#  os\n"
#  numpy as np\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  seaborn as sns"
#    ]
#   }
#  random\n"
#  choices \n"
#  Provider\n"
#  Provider\n"
#  seaborn as sns\n"
#  pandas as pd\n"
#  pandas as pd\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy\n"
#  numpy as np\n"
#  seaborn as sns\n"
#  pandas as pd\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy\n"
#  numpy as np\n"
#  time\n"
#  pandas\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  time\n"
#  pandas\n"
#  time\n"
#  pandas\n"
#  pandas\n"
#  or set low_memory=False.\n"
#  time\n"
#  pandas\n"
#  pandas as pd\n"
#  missingno as msno"
#    ]
#   }
#  matplotlib.pylab as plt"
#    ]
#   }
#  time\n"
#  pandas\n"
#  time\n"
#  pandas\n"
#  pandas as pd\n"
#  matplotlib.pylab as plt"
#    ]
#   }
#  time\n"
#  pandas\n"
#  matplotlib.pyplot as plt"
#    ]
#   }
#  pandas\n"
#  or set low_memory=False.\n"
#  pandas as pd\n"
#  matplotlib.pylab as plt"
#    ]
#   }
#  pandas as pd\n"
#  seaborn\n"
#  seaborn as sns\n"
#  pyplot as plt\n"
#  numpy\n"
#  numpy as np"
#    ]
#   }
#  seaborn as sns\n"
#  seaborn as sns\n"
#  random \n"
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  Counter\n"
#  OrderedDict"
#    ]
#   }
#  random\n"
#  random\n"
#  datetime\n"
#  re\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  random\n"
#  random\n"
#  datetime\n"
#  re\n"
#  pandas as pd\n"
#  random\n"
#  datetime\n"
#  re\n"
#  pandas\n"
#  pandas as pd\n"
#  numpy as np\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  pandas as pd\n"
#  pandas as pd\n"
#  pandas\n"
#  pandas as pd\n"
#  numpy as np\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  random \n"
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  Counter\n"
#  OrderedDict"
#    ]
#   }
#  pandas as pd\n"
#  os\n"
#  pyplot as plt\n"
#  seaborn as sns"
#    ]
#   }
#  os\n"
#  random \n"
#  matplotlib.pyplot as plt\n"
#  numpy as np\n"
#  Counter\n"
#  OrderedDict"
#    ]
#   }
#  pandas as pd\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  matplotlib.pyplot as plt\n"
#  os\n"
#  os\n"
